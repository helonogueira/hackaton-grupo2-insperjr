# %% [markdown]
# ## Análise por cerveja por semana

# %%
import pandas as pd
from pyxlsb import open_workbook

FILE_PATH = r"C:\Users\ferna\Downloads\AMBEV\separado.por.cerveja.xlsb"

def get_bloco_dict(header, start, next_start):
    end = next_start if next_start else len(header)
    result = {}
    for i in range(start, end):
        val = str(header[i]).strip()
        if val not in ["", "None", "nan"]:
            result[val] = i
    return result

def ler_aba(sheet_name):
    rows = []
    with open_workbook(FILE_PATH) as wb:
        with wb.get_sheet(sheet_name) as sheet:
            for row in sheet.rows():
                rows.append([c.v for c in row])

    raw = pd.DataFrame(rows)

    header_row_idx = None
    for i, row in raw.iterrows():
        if row.astype(str).str.strip().str.lower().eq("demanda").any():
            header_row_idx = i
            break

    header = raw.iloc[header_row_idx].tolist()
    data   = raw.iloc[header_row_idx + 1:].reset_index(drop=True)

    semana_starts = [i for i, h in enumerate(header) if str(h).strip().lower() == "demanda"]
    COL_REGIAO    = next(i for i, h in enumerate(header) if str(h).strip() not in ["", "None", "nan"])

    records = []
    for idx_semana, col_start in enumerate(semana_starts):
        next_start = semana_starts[idx_semana + 1] if idx_semana + 1 < len(semana_starts) else None
        bloco = get_bloco_dict(header, col_start, next_start)

        def get_col(row, nomes):
            for n in nomes:
                if n in bloco:
                    return pd.to_numeric(row.iloc[bloco[n]], errors="coerce")
            return None

        for _, row in data.iterrows():
            regiao = row.iloc[COL_REGIAO]
            if pd.isna(regiao) or str(regiao).strip() in ["", "None", "TOTAL"]:
                continue

            records.append({
                "Cerveja":       sheet_name,
                "Regiao":        str(regiao).strip(),
                "Semana":        f"W{idx_semana}",
                "Demanda":       get_col(row, ["Demanda"]),
                "WSNP":          get_col(row, ["WSNP", "Malha", "0.0"]),
                "EI_Semana":     get_col(row, ["EI Semana"]),
                "Suf_in":        get_col(row, ["Suf.ini(d)"]),
                "Transi_Intern": get_col(row, ["Transf. Interna"]),
                "Transi_Cabo":   get_col(row, ["Transf. Ext (Cabo)"]),
                "Transi_Rodo":   get_col(row, ["Transf. Ext (Rodo)"]),
                "Transito":      get_col(row, ["Trânsito"]),
                "EF_Semana":     get_col(row, ["EF Semana"]),
                "Suf_f":         get_col(row, ["Suf. f (d)"]),
            })

    return pd.DataFrame(records)

# ── Ler todas as abas ─────────────────────────────────────────────────────────
abas = ["patagonia", "goose", "malzbier ", "colorado "]
df_all = pd.concat([ler_aba(a) for a in abas], ignore_index=True)

# ── Exibir por cerveja e semana ───────────────────────────────────────────────
for cerveja, df_cerv in df_all.groupby("Cerveja"):
    print(f"\n{'#'*60}")
    print(f"  {cerveja.upper()}")
    print(f"{'#'*60}")
    for semana, grupo in df_cerv.groupby("Semana"):
        print(f"\n{'='*60}  {semana}  {'='*60}")
        display(grupo.reset_index(drop=True))
ei_suf_w0 = df_all[df_all["Semana"] == "W0"][["Cerveja", "Regiao", "EI_Semana", "Suf_in"]]
# Out:
# ############################################################
#   COLORADO
# ############################################################
#
# ============================================================  W0  ============================================================
#      Cerveja       Regiao Semana   Demanda    WSNP  EI_Semana     Suf_in  \
# 0  colorado        Mapapi     W0  1854.198     0.0   3877.200  12.546233
# 1  colorado      NE Norte     W0  1370.880  5400.0   8016.278  35.085250
# 2  colorado        NE Sul     W0  1199.718     0.0   5080.104  25.406491
# 3  colorado   NO Araguaia     W0    48.114     0.0      0.000   0.000000
# 4  colorado     NO Centro     W0  1579.266     0.0   4416.696  16.780059
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana      Suf_f
# 0     2891.44836          0.0          0.0       0.0  4914.45036  15.117385
# 1    -4225.04262          0.0          0.0       0.0  7820.35538  28.970395
# 2      228.44160          0.0          0.0       0.0  4108.82760  17.807484
# 3       48.11058          0.0          0.0       0.0    -0.00342  -0.000357
# 4     1056.66468          0.0          0.0       0.0  3894.09468  13.736801
# ============================================================  W1  ============================================================
#      Cerveja       Regiao Semana   Demanda  WSNP  EI_Semana  Suf_in  \
# 0  colorado        Mapapi     W1  1950.516   0.0        NaN     NaN
# 1  colorado      NE Norte     W1  1619.658   0.0        NaN     NaN
# 2  colorado        NE Sul     W1  1384.416   0.0        NaN     NaN
# 3  colorado   NO Araguaia     W1    57.474   0.0        NaN     NaN
# 4  colorado     NO Centro     W1  1700.874   0.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana      Suf_f
# 0     1112.50674          0.0          0.0       0.0  4076.44110  17.169529
# 1    -3080.02788          0.0          0.0       0.0  3120.66950  14.772120
# 2      525.88278          0.0          0.0       0.0  3250.29438  18.542066
# 3       38.14938          0.0          0.0       0.0   -19.32804  -2.977209
# 4     1403.23998       -228.0          0.0       0.0  3368.46066  16.545396
# ============================================================  W2  ============================================================
#      Cerveja       Regiao Semana   Demanda     WSNP  EI_Semana  Suf_in  \
# 0  colorado        Mapapi     W2  1424.538      0.0        NaN     NaN
# 1  colorado      NE Norte     W2  1267.524  10800.0        NaN     NaN
# 2  colorado        NE Sul     W2  1051.758      0.0        NaN     NaN
# 3  colorado   NO Araguaia     W2    38.952      0.0        NaN     NaN
# 4  colorado     NO Centro     W2  1221.534      0.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana      Suf_f
# 0     1008.97218          0.0          0.0       0.0  3660.87528  13.361200
# 1    -3487.03506          0.0          0.0       0.0  9166.11044  39.375864
# 2     1107.11232          0.0          0.0       0.0  3305.64870  17.338561
# 3       38.93814          0.0          0.0       0.0   -19.34190  -2.845234
# 4     1332.31668       -375.0          0.0       0.0  3104.24334  13.394273
# ============================================================  W3  ============================================================
#      Cerveja       Regiao Semana   Demanda  WSNP  EI_Semana  Suf_in  \
# 0  colorado        Mapapi     W3  1643.958   0.0        NaN     NaN
# 1  colorado      NE Norte     W3  1396.710   0.0        NaN     NaN
# 2  colorado        NE Sul     W3  1143.918   0.0        NaN     NaN
# 3  colorado   NO Araguaia     W3    40.788   0.0        NaN     NaN
# 4  colorado     NO Centro     W3  1390.554   0.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana      Suf_f
# 0      966.72078          0.0          0.0       0.0  2983.63806  10.889468
# 1    -3721.33008          0.0          0.0       0.0  4048.07036  17.389739
# 2     1130.41728          0.0          0.0       0.0  3292.14798  17.267748
# 3       40.79232          0.0          0.0       0.0   -19.33758  -2.844598
# 4     1583.39630       -389.0          0.0       0.0  2908.08564  12.547887
# ############################################################
#   GOOSE
# ############################################################
#
# ============================================================  W0  ============================================================
#   Cerveja       Regiao Semana   Demanda    WSNP  EI_Semana     Suf_in  \
# 0   goose       Mapapi     W0  4732.542     0.0   5705.586   7.233642
# 1   goose     NE Norte     W0  3887.460  5400.0  12370.842  19.093457
# 2   goose       NE Sul     W0  3197.214     0.0   6338.004  11.894113
# 3   goose  NO Araguaia     W0   157.212     0.0      0.000   0.000000
# 4   goose    NO Centro     W0  2867.508     0.0   3187.476   6.669504
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito    EF_Semana      Suf_f
# 0     4246.05870          0.0          0.0       0.0   5219.10270   5.863482
# 1    -3505.87958       2083.0          0.0    2000.0  12377.50242  19.360933
# 2    -4166.00000      13243.0          0.0    2500.0   1474.79000   2.818449
# 3        0.00000          0.0          0.0       0.0   -157.21200  -4.864835
# 4     3426.24582          0.0          0.0       0.0   3746.21382   7.570449
# ============================================================  W1  ============================================================
#   Cerveja       Regiao Semana   Demanda     WSNP  EI_Semana  Suf_in  \
# 0   goose       Mapapi     W1  5340.618      0.0        NaN     NaN
# 1   goose     NE Norte     W1  3835.818  14400.0        NaN     NaN
# 2   goose       NE Sul     W1  3139.578      0.0        NaN     NaN
# 3   goose  NO Araguaia     W1   193.896      0.0        NaN     NaN
# 4   goose    NO Centro     W1  2969.082      0.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito    EF_Semana      Suf_f
# 0     5220.62172          0.0          0.0       0.0   5099.10642   7.969085
# 1   -11113.71592       2830.0          0.0       0.0  11827.96850  23.736784
# 2     2834.42120      10000.0          0.0       0.0   1169.63320   2.941208
# 3      193.90266          0.0          0.0       0.0   -157.20534  -6.876874
# 4     2864.71440          0.0          0.0       0.0   3641.84622   9.304286
# ============================================================  W2  ============================================================
#   Cerveja       Regiao Semana   Demanda  WSNP  EI_Semana  Suf_in  \
# 0   goose       Mapapi     W2  3839.166   0.0        NaN     NaN
# 1   goose     NE Norte     W2  2989.782   0.0        NaN     NaN
# 2   goose       NE Sul     W2  2386.026   0.0        NaN     NaN
# 3   goose  NO Araguaia     W2   137.160   0.0        NaN     NaN
# 4   goose    NO Centro     W2  2348.496   0.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana      Suf_f
# 0     1491.73650          0.0          0.0       0.0  2751.67692   3.792869
# 1    -2268.08990       2762.0          0.0       0.0  6570.09660  11.942721
# 2     -768.08134      10000.0          0.0       0.0 -1984.47414  -4.438944
# 3      137.15766          0.0          0.0       0.0  -157.20768  -6.481455
# 4     1406.82474          0.0          0.0       0.0  2700.17496   6.309380
# ============================================================  W3  ============================================================
#   Cerveja       Regiao Semana   Demanda     WSNP  EI_Semana  Suf_in  \
# 0   goose       Mapapi     W3  4352.922      0.0        NaN     NaN
# 1   goose     NE Norte     W3  3300.804  12600.0        NaN     NaN
# 2   goose       NE Sul     W3  2682.360      0.0        NaN     NaN
# 3   goose  NO Araguaia     W3   145.530      0.0        NaN     NaN
# 4   goose    NO Centro     W3  2567.772      0.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito    EF_Semana      Suf_f
# 0     4386.88260          0.0          0.0       0.0   2785.63752   3.839679
# 1    -9623.25034       2770.0          0.0    2083.0   8329.04226  15.140025
# 2     2719.30652      10000.0          0.0   13243.0  11295.47238  25.266122
# 3      145.53774          0.0          0.0       0.0   -157.19994  -6.481135
# 4     2371.26330          0.0          0.0       0.0   2503.66626   5.850207
# ############################################################
#   MALZBIER
# ############################################################
#
# ============================================================  W0  ============================================================
#      Cerveja       Regiao Semana    Demanda     WSNP  EI_Semana    Suf_in  \
# 0  malzbier        Mapapi     W0  6074.8038      0.0   1985.616  1.961166
# 1  malzbier      NE Norte     W0  1971.7542  16200.0    302.004  0.918991
# 2  malzbier        NE Sul     W0  3230.3466      0.0   4383.000  8.140922
# 3  malzbier   NO Araguaia     W0    78.8580      0.0      0.000  0.000000
# 4  malzbier     NO Centro     W0  2227.5162      0.0    964.818  2.598817
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana      Suf_f
# 0     5050.04832          0.0          0.0       0.0   960.86052   0.917084
# 1    -9281.16846          0.0          0.0       0.0  5249.08134  13.899950
# 2     3054.15054          0.0          0.0       0.0  4206.80394   7.175571
# 3       60.65568          0.0          0.0       0.0   -18.20232  -1.175929
# 4     1116.53520          0.0          0.0       0.0  -146.16300  -0.356049
# ============================================================  W1  ============================================================
#      Cerveja       Regiao Semana    Demanda    WSNP  EI_Semana  Suf_in  \
# 0  malzbier        Mapapi     W1  6286.4100     0.0        NaN     NaN
# 1  malzbier      NE Norte     W1  2265.7986     0.0        NaN     NaN
# 2  malzbier        NE Sul     W1  3517.6050     0.0        NaN     NaN
# 3  malzbier   NO Araguaia     W1    92.8746     0.0        NaN     NaN
# 4  malzbier     NO Centro     W1  2463.0840  9000.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana     Suf_f
# 0     6161.58468          0.0          0.0       0.0   836.03520  1.178060
# 1     -723.14280          0.0          0.0       0.0  2260.13994  7.940086
# 2      316.95048          0.0          0.0       0.0  1006.14942  2.331665
# 3       71.43354          0.0          0.0       0.0   -39.64338 -3.780204
# 4    -5826.65288          0.0          0.0       0.0   564.10012  1.891252
# ============================================================  W2  ============================================================
#      Cerveja       Regiao Semana    Demanda     WSNP  EI_Semana  Suf_in  \
# 0  malzbier        Mapapi     W2  4258.0278      0.0        NaN     NaN
# 1  malzbier      NE Norte     W2  1707.8958  12960.0        NaN     NaN
# 2  malzbier        NE Sul     W2  2589.0930      0.0        NaN     NaN
# 3  malzbier   NO Araguaia     W2    62.9226      0.0        NaN     NaN
# 4  malzbier     NO Centro     W2  1789.6086   7560.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana      Suf_f
# 0     2792.98818          0.0          0.0       0.0  -629.00442  -0.725135
# 1   -10468.70838          0.0          0.0       0.0  3043.53576   9.903097
# 2     7662.10268          0.0          0.0       0.0  6079.15910  12.765724
# 3       48.39048          0.0          0.0       0.0   -54.17550  -4.932938
# 4      -34.37550          0.0          0.0       0.0  6300.11602  18.658486
# ============================================================  W3  ============================================================
#      Cerveja       Regiao Semana    Demanda  WSNP  EI_Semana  Suf_in  \
# 0  malzbier        Mapapi     W3  5204.5812   0.0        NaN     NaN
# 1  malzbier      NE Norte     W3  1843.9902   0.0        NaN     NaN
# 2  malzbier        NE Sul     W3  2857.2570   0.0        NaN     NaN
# 3  malzbier   NO Araguaia     W3    65.8944   0.0        NaN     NaN
# 4  malzbier     NO Centro     W3  2025.9252   0.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Sem
0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana      Suf_f
# 0     1726.37370          0.0          0.0       0.0  2778.86106   7.150366
# 1     1735.92756          0.0          0.0       0.0  4064.64228  12.151179
# 2      376.32960          0.0          0.0       0.0  3858.16752  13.378716
# 3       92.09898          0.0          0.0       0.0     0.00216   0.000134
# 4    -3930.65812        -35.0          0.0       0.0  -273.84582  -1.272772
# ============================================================  W3  ============================================================
#      Cerveja       Regiao Semana   Demanda     WSNP  EI_Semana  Suf_in  \
# 0  patagonia       Mapapi     W3  2331.792      0.0        NaN     NaN
# 1  patagonia     NE Norte     W3  2007.036      0.0        NaN     NaN
# 2  patagonia       NE Sul     W3  1730.286      0.0        NaN     NaN
# 3  patagonia  NO Araguaia     W3    96.498      0.0        NaN     NaN
# 4  patagonia    NO Centro     W3  1290.942  12600.0        NaN     NaN
#
#    Transi_Intern  Transi_Cabo  Transi_Rodo  Transito   EF_Semana      Suf_f
# 0     3298.08654          0.0          0.0       0.0  3745.15560   9.636766
# 1     1695.43332          0.0          0.0       0.0  3753.03960  11.219648
# 2     5200.78914          0.0          0.0       0.0  7328.67066  25.413154
# 3       96.48468          0.0          0.0       0.0    -0.01116  -0.000694
# 4   -10290.65986      -1088.0          0.0       0.0  -343.44768  -1.596265

# %%
# Out:
# ['Cenário atual BR', 'Custos de transferência', 'Produção PCP', 'Transferências Programadas', 'Cenário Divulgado', 'Cenário com Nova Demanda', 'patagonia', 'goose', 'malzbier ', 'colorado ', 'Sheet5']

# %%
import pandas as pd
from pyxlsb import open_workbook

FILE_PATH = r"C:\Users\ferna\Downloads\AMBEV\separado.por.cerveja.xlsb"
SHEET_NAME = "Cenário atual BR"

rows = []
with open_workbook(FILE_PATH) as wb:
    with wb.get_sheet(SHEET_NAME) as sheet:
        for row in sheet.rows():
            rows.append([c.v for c in row])

raw = pd.DataFrame(rows)

# Regiões válidas
regioes = ["MG", "SP", "NENO", "CO", "RJ", "SUL", "Export", "TOTAL"]

# Colunas Janeiro (índices da linha 4)
cols_jan = {
    "Regiao":      2,
    "Demanda":     3,
    "Prod_Real":   5,
    "WSNP":        6,
    "Prod_1W":     7,  # Real col 7
    "Prod_Prog":   8,  # 1W col 8
    "EI_Mes":      10,
    "Suf_ini":     11,
    "Transf_Malha":12,
    "EFM":         13,
    "Suf_f":       14,
}

# Colunas Fevereiro (índices da linha 4)
cols_fev = {
    "Regiao":       16,
    "Demanda":      17,
    "WSNP":         19,
    "Transf_Malha": 21,
    "EFM":          22,
    "Suf_f":        23,
}
print("=== CENÁRIO ATUAL BR ===")
for mes, grupo in df_br.groupby("Mes"):
    print(f"\n{'='*60}  {mes}  {'='*60}")
    display(grupo.reset_index(drop=True))
# Out:
# === CENÁRIO ATUAL BR ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 43
#      34 cols_fev = {
#      35     "Regiao":       16,
#      36     "Demanda":      17,
#    (...)
#      40     "Suf_f":        23,
#      41 }
#      42 print("=== CENÁRIO ATUAL BR ===")
# ---> 43 for mes, grupo in df_br.groupby("Mes"):
#      44     print(f"\n{'='*60}  {mes}  {'='*60}")
#      45     display(grupo.reset_index(drop=True))
#
# NameError: name 'df_br' is not defined

# %% [markdown]
# ## Transferencia dpatagonia entro do neno

# %%
df_pat = df_all[df_all["Cerveja"] == "patagonia"].copy()

ei_w0 = df_pat[df_pat["Semana"] == "W0"].set_index("Regiao")["EI_Semana"].to_dict()

prod_ce_pat = {"W0": 12240, "W1": 1800, "W2": 5040, "W3": 12600}

semanas = ["W0", "W1", "W2", "W3"]
regioes = sorted(df_pat["Regiao"].unique().tolist())

estoque = {r: float(ei_w0.get(r, 0) or 0) for r in regioes}

# Demanda por região e semana
dem_dict = {}
for sem in semanas:
    dem_dict[sem] = df_pat[df_pat["Semana"] == sem].set_index("Regiao")["Demanda"].to_dict()

resultados = []

for i, sem in enumerate(semanas):
    prod_disp  = prod_ce_pat.get(sem, 0)
    prox_sem   = semanas[i + 1] if i + 1 < len(semanas) else None

    nec = {}
    for r in regioes:
        dem      = dem_dict[sem].get(r, 0)
        ei       = estoque[r]

        # EF alvo baseado na demanda da semana SEGUINTE
        if prox_sem:
            dem_prox = dem_dict[prox_sem].get(r, 0)
            ef_alvo  = 12 * (dem_prox / 6)
        else:
            ef_alvo  = 12 * (dem / 6)  # W3: usa própria demanda

        envio_nec = max(0, ef_alvo + dem - ei)
        nec[r] = {"dem": dem, "ei": ei, "ef_alvo": ef_alvo, "envio_nec": envio_nec}

    total_nec = sum(v["envio_nec"] for v in nec.values())

    for r in regioes:
        dem       = nec[r]["dem"]
        ei        = nec[r]["ei"]
        ef_alvo   = nec[r]["ef_alvo"]
        envio_nec = nec[r]["envio_nec"]

        envio_ce  = prod_disp * (envio_nec / total_nec) if total_nec > 0 else 0
        vem_sp    = max(0, envio_nec - envio_ce)

        if sem in ["W0", "W1", "W2"]:
            modal         = "Rodoviário"
            vol_enviar_sp = vem_sp / 0.95
        else:
            modal         = "Cabotagem"
            vol_enviar_sp = vem_sp

        ef    = ei + envio_ce + vem_sp - dem
        dem_prox = dem_dict[prox_sem].get(r, 0) if prox_sem else dem
        suf_f = ef / (dem_prox / 6) if dem_prox > 0 else 0

        resultados.append({
            "Semana":        sem,
            "Regiao":        r,
            "Demanda":       round(dem, 2),
            "Dem_Proxima":   round(dem_prox, 2),
            "EI":            round(ei, 2),
            "Prod_CE":       round(envio_ce, 2),
            "Vem_SP":        round(vem_sp, 2),
            "Vol_Enviar_SP": round(vol_enviar_sp, 2),
            "Modal_SP":      modal if vem_sp > 0 else "-",
            "EF":            round(ef, 2),
            "Suf_f":         round(suf_f, 1),
        })

        estoque[r] = ef

df_res = pd.DataFrame(resultados)

print("=== DISTRIBUIÇÃO PATAGONIA — SUF_F ALVO = 12 (dem próxima / 6) ===")
for sem, grupo in df_res.groupby("Semana"):
    print(f"\n{'='*50}  {sem}  {'='*50}")
    display(grupo.reset_index(drop=True))

print("\n=== REGIÕES QUE PRECISAM DE SP ===")
sp = df_res[df_res["Vem_SP"] > 0][["Semana","Regiao","Demanda","Prod_CE","Vem_SP","Vol_Enviar_SP","Modal_SP","Suf_f"]]
display(sp if len(sp) > 0 else pd.DataFrame([{"Resultado": "Nenhuma transferência necessária!"}]))
# Out:
# === DISTRIBUIÇÃO PATAGONIA — SUF_F ALVO = 12 (dem próxima / 6) ===
#
# ==================================================  W0  ==================================================
#   Semana       Regiao  Demanda  Dem_Proxima       EI  Prod
vol_Enviar_SP Modal_SP       EF  Suf_f
# 0            0.0        -  6319.64   16.3
# 1            0.0        -  5439.49   16.3
# 2            0.0        -  4689.44   16.3
# 3            0.0        -   198.30   12.3
# 4            0.0        -  3498.72   16.3
# === REGIÕES QUE PRECISAM DE SP ===
#    Semana     Regiao  Demanda  Prod_CE  Vem_SP  Vol_Enviar_SP    Modal_SP  \
# 10     W2     Mapapi  2162.11   903.37  119.95         126.27  Rodoviário
# 11     W2   NE Norte  1822.45  1803.84  239.52         252.13  Rodoviário
# 12     W2     NE Sul  1564.06  1379.07  183.12         192.76  Rodoviário
# 14     W2  NO Centro  1162.17   953.72  126.64         133.31  Rodoviário
#
#     Suf_f
# 10   12.0
# 11   12.0
# 12   12.0
# 14   12.0

# %%
print("=== PRODUÇÃO TOTAL CE POR SEMANA ===")
display(df_res.groupby("Semana")["Prod_CE"].sum().reset_index().rename(columns={"Prod_CE": "Total_Prod_CE"}))
# Out:
# === PRODUÇÃO TOTAL CE POR SEMANA ===
#   Semana  Total_Prod_CE
# 0     W0       12239.99
# 1     W1        1800.00
# 2     W2        5040.00
# 3     W3       12600.00

# %% [markdown]
# # Transferencia todas as cervejas - mes de fevereiro - dentro do neno

# %%
# Produção por cerveja/fábrica/semana (valores da foto)
producao = {
    "patagonia": {"CE": {"W0": 12240, "W1": 1800,  "W2": 5040,  "W3": 12600},
                  "PE": {"W0": 0,     "W1": 0,      "W2": 0,     "W3": 0}},
    "malzbier ":  {"CE": {"W0": 0,     "W1": 9000,   "W2": 7560,  "W3": 0},
                  "PE": {"W0": 16200, "W1": 0,      "W2": 12960, "W3": 0}},
    "colorado ":  {"CE": {"W0": 0,     "W1": 0,      "W2": 0,     "W3": 0},
                  "PE": {"W0": 5400,  "W1": 0,      "W2": 10800, "W3": 0}},
    "goose":     {"CE": {"W0": 0,     "W1": 0,      "W2": 0,     "W3": 0},
                  "PE": {"W0": 5400,  "W1": 14400,  "W2": 0,     "W3": 12600}},
}

def analisar_cerveja(cerveja, df_all, producao):
    df_cerv = df_all[df_all["Cerveja"] == cerveja].copy()

    ei_w0 = df_cerv[df_cerv["Semana"] == "W0"].set_index("Regiao")["EI_Semana"].to_dict()

    semanas = ["W0", "W1", "W2", "W3"]
    regioes = sorted(df_cerv["Regiao"].unique().tolist())

    dem_dict = {}
    for sem in semanas:
        dem_dict[sem] = df_cerv[df_cerv["Semana"] == sem].set_index("Regiao")["Demanda"].to_dict()

    estoque = {r: float(ei_w0.get(r, 0) or 0) for r in regioes}
    resultados = []

    for i, sem in enumerate(semanas):
        prod_ce   = producao[cerveja]["CE"].get(sem, 0)
        prod_pe   = producao[cerveja]["PE"].get(sem, 0)
        prod_disp = prod_ce + prod_pe
        prox_sem  = semanas[i + 1] if i + 1 < len(semanas) else None

        nec = {}
        for r in regioes:
            dem     = dem_dict[sem].get(r, 0)
            ei      = estoque[r]
            dem_prox = dem_dict[prox_sem].get(r, 0) if prox_sem else dem
            ef_alvo  = 12 * (dem_prox / 6)
            envio_nec = max(0, ef_alvo + dem - ei)
            nec[r] = {"dem": dem, "ei": ei, "ef_alvo": ef_alvo,
                      "envio_nec": envio_nec, "dem_prox": dem_prox}

        total_nec = sum(v["envio_nec"] for v in nec.values())

        for r in regioes:
            dem       = nec[r]["dem"]
            ei        = nec[r]["ei"]
            ef_alvo   = nec[r]["ef_alvo"]
            envio_nec = nec[r]["envio_nec"]
            dem_prox  = nec[r]["dem_prox"]

            envio_prod = prod_disp * (envio_nec / total_nec) if total_nec > 0 else 0
            vem_sp     = max(0, envio_nec - envio_prod)

            if sem in ["W0", "W1", "W2"]:
                modal         = "Rodoviário"
                vol_enviar_sp = vem_sp / 0.95
            else:
                modal         = "Cabotagem"
                vol_enviar_sp = vem_sp

            ef    = ei + envio_prod + vem_sp - dem
            suf_f = ef / (dem_prox / 6) if dem_prox > 0 else 0

            resultados.append({
                "Cerveja":       cerveja,
                "Semana":        sem,
                "Regiao":        r,
                "Demanda":       round(dem, 2),
                "Dem_Proxima":   round(dem_prox, 2),
                "EI":            round(ei, 2),
                "Prod_NE":       round(envio_prod, 2),
                "Vem_SP":        round(vem_sp, 2),
                "Vol_Enviar_SP": round(vol_enviar_sp, 2),
                "Modal_SP":      modal if vem_sp > 0 else "-",
                "EF":            round(ef, 2),
                "Suf_f":         round(suf_f, 1),
            })

            estoque[r] = ef

    return pd.DataFrame(resultados)

# ── Roda para todas as cervejas ───────────────────────────────────────────────
cervejas = ["patagonia", "malzbier ", "colorado ", "goose"]
df_final = pd.concat([analisar_cerveja(c, df_all, producao) for c in cervejas], ignore_index=True)

# ── Exibe por cerveja e semana ────────────────────────────────────────────────
for cerveja, df_c in df_final.groupby("Cerveja"):
    print(f"\n{'#'*60}  {cerveja.upper()}  {'#'*60}")
    for sem, grupo in df_c.groupby("Semana"):
        print(f"\n{'='*50}  {sem}  {'='*50}")
        display(grupo.reset_index(drop=True))

# ── Resumo SP ─────────────────────────────────────────────────────────────────
print("\n=== RESUMO — O QUE VEM DE SP ===")
sp = df_final[df_final["Vem_SP"] > 0][["Cerveja","Semana","Regiao","Demanda","Prod_NE","Vem_SP","Vol_Enviar_SP","Modal_SP","Suf_f"]]
display(sp if len(sp) > 0 else pd.DataFrame([{"Resultado": "Nenhuma transferência necessária!"}]))

# ── Produção total por cerveja/semana ─────────────────────────────────────────
print("\n=== PRODUÇÃO TOTAL NE POR CERVEJA/SEMANA ===")
display(df_final.groupby(["Cerveja","Semana"])["Prod_NE"].sum().reset_index())
# Out:
# ############################################################  COLORADO   ############################################################
#
# ==================================================  W0  ==================================================
#      Cerveja Semana       Regiao  Demanda  Dem_Proxima       EI  Prod_NE  \
# 0  colorado      W0       Mapapi  1854.20      1950.52  3877.20  3892.42
# 1  colorado      W0     NE Norte  1370.88      1619.66  8016.28     0.00
# 2  colorado      W0       NE Sul  1199.72      1384.42  5080.10     0.00
# 3  colorado      W0  NO Araguaia    48.11        57.47     0.00   337.96
# 4  colorado      W0    NO Centro  1579.27      1700.87  4416.70  1169.61
#
#    Vem_SP  Vol_Enviar_SP Modal_SP       EF  Suf_f
# 0     0.0            0.0        -  5915.43   18.2
# 1     0.0            0.0        -  6645.40   24.6
# 2     0.0            0.0        -  3880.39   16.8
# 3     0.0            0.0        -   289.85   30.3
# 4     0.0            0.0        -  4007.04   14.1
# ==================================================  W1  ==================================================
#      Cerveja Semana       Regiao  Demanda  Dem_Proxima       EI  Prod_NE  \
# 0
# 37  malzbier      W3       NE Sul  2857.26     0.00   713.48         713.48
# 38  malzbier      W3  NO Araguaia    65.89     0.00    17.17          17.17
# 39  malzbier      W3    NO Centro  2025.93     0.00   438.98         438.98
# 49  colorado      W1    NO Centro  1700.87     0.00   136.90         144.11
# 56  colorado      W3     NE Norte  1396.71     0.00   431.91         431.91
# 60      goose     W0       Mapapi  4732.54  2757.75  6950.44        7316.25
# 62      goose     W0       NE Sul  3197.21   891.50  2246.87        2365.12
# 63      goose     W0  NO Araguaia   157.21   154.82   390.19         410.72
# 64      goose     W0    NO Centro  2867.51  1595.93  4022.27        4233.96
# 70      goose     W2       Mapapi  3839.17     0.00  2470.13        2600.14
# 71      goose     W2     NE Norte  2989.78     0.00  2246.30        2364.53
# 72      goose     W2       NE Sul  2386.03     0.00  1305.13        1373.83
# 73      goose     W2  NO Araguaia   137.16     0.00    71.45          75.21
# 74      goose     W2    NO Centro  2348.50     0.00  1015.65        1069.11
# 75      goose     W3       Mapapi  4352.92  4203.02   149.90         149.90
# 76      goose     W3     NE Norte  3300.80  3187.13   113.67         113.67
# 77      goose     W3       NE Sul  2682.36  2589.99    92.37          92.37
# 78      goose     W3  NO Araguaia   145.53   140.52     5.01           5.01
# 79      goose     W3    NO Centro  2567.77  2479.34    88.43          88.43
#
#       Modal_SP  Suf_f
# 10  Rodoviário   12.0
# 11  Rodoviário   12.0
# 12  Rodoviário   12.0
# 14  Rodoviário   12.0
# 20  Rodoviário   12.0
# 21  Rodoviário   12.0
# 22  Rodoviário   12.0
# 23  Rodoviário   12.0
# 24  Rodoviário   12.0
# 35   Cabotagem   12.0
# 36   Cabotagem   12.0
# 37   Cabotagem   12.0
# 38   Cabotagem   12.0
# 39   Cabotagem   12.0
# 49  Rodoviário   12.0
# 56   Cabotagem   12.0
# 60  Rodoviário   12.0
# 62  Rodoviário   12.0
# 63  Rodoviário   12.0
# 64  Rodoviário   12.0
# 70  Rodoviário   12.0
# 71  Rodoviário   12.0
# 72  Rodoviário   12.0
# 73  Rodoviário   12.0
# 74  Rodoviário   12.0
# 75   Cabotagem   12.0
# 76   Cabotagem   12.0
# 77   Cabotagem   12.0
# 78   Cabotagem   12.0
# 79   Cabotagem   12.0
# === PRODUÇÃO TOTAL NE POR CERVEJA/SEMANA ===
#       Cerveja Semana   Prod_NE
# 0   colorado      W0   5399.99
# 1   colorado      W1      0.00
# 2   colorado      W2  10799.99
# 3   colorado      W3      0.00
# 4       goose     W0   5400.00
# 5       goose     W1  14399.99
# 6       goose     W2      0.00
# 7       goose     W3  12600.00
# 8   malzbier      W0  16199.99
# 9   malzbier      W1   9000.00
# 10  malzbier      W2  20520.00
# 11  malzbier      W3      0.00
# 12  patagonia     W0  12239.99
# 13  patagonia     W1   1800.00
# 14  patagonia     W2   5040.00
# 15  patagonia     W3  12600.00

# %%
print(df_all["Cerveja"].unique())
# Out:
# ['patagonia' 'goose' 'malzbier ' 'colorado ']
